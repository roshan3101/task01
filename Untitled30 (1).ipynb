# %%
import pandas as pd
import numpy as np

# %%
users = pd.read_csv("/content/user_personalized_features.csv").drop(columns=["Unnamed: 0"])

# %%
users
# Out:
#     User_ID  Age  Gender  Location  Income   Interests  Last_Login_Days_Ago  \
# 0        #1   56    Male  Suburban   38037      Sports                    5
# 1        #2   46  Female     Rural  103986  Technology                   15
# 2        #3   32  Female  Suburban  101942      Sports                   28
# 3        #4   60  Female  Suburban   71612     Fashion                   18
# 4        #5   25    Male  Suburban   49725      Travel                    2
# ..      ...  ...     ...       ...     ...         ...                  ...
# 995    #996   22    Male     Urban  104162  Technology                   18
# 996    #997   40    Male     Urban   99003      Travel                   16
# 997    #998   27  Female     Urban   72395  Technology                    8
# 998    #999   61    Male     Rural   59758      Travel                    1
# 999   #1000   19    Male     Rural   74312      Sports                   12
#
#      Purchase_Frequency  Average_Order_Value  Total_Spending  \
# 0                     7                   18            2546
# 1                     7                  118             320
# 2                     1                  146            3766
# 3                     3                  163            4377
# 4                     5                  141            4502
# ..                  ...                  ...             ...
# 995                   7                   83             607
# 996                   3                  180             431
# 997                   8                  130             650
# 998                   3                  152            1041
# 999                   7                  175             827
#
#     Product_Category_Preference  Time_Spent_on_Site_Minutes  Pages_Viewed  \
# 0                         Books                         584            38
# 1                   Electronics                         432            40
# 2                       Apparel                         306             1
# 3                       Apparel                         527            29
# 4               Health & Beauty                          53            10
# ..                          ...                         ...           ...
# 995                     Apparel                         542            21
# 996                     Apparel                         359             4
# 997                       Books                         331            34
# 998                 Electronics                         427            28
# 999             Health & Beauty                         497            38
#
#      Newsletter_Subscription
# 0                       True
# 1                      False
# 2                       True
# 3                      False
# 4                       True
# ..                       ...
# 995                    False
# 996                     True
# 997                    False
# 998                     True
# 999                     True
#
# [1000 rows x 14 columns]

# %%
users.Interests.unique()
# Out:
# array(['Sports', 'Technology', 'Fashion', 'Travel', 'Food'], dtype=object)

# %%
users.Product_Category_Preference.unique()
# Out:
# array(['Books', 'Electronics', 'Apparel', 'Health & Beauty',
#        'Home & Kitchen'], dtype=object)

# %%
products = pd.read_csv("/content/products.csv")

# %%
products
# Out:
#      product_id                             title         category  \
# 0             1    Storage Home & Kitchen Product   Home & Kitchen
# 1             2   Cookware Home & Kitchen Product   Home & Kitchen
# 2             3          Non-fiction Book Product            Books
# 3             4  Skincare Health & Beauty Product  Health & Beauty
# 4             5            Summer Apparel Product          Apparel
# ..          ...                               ...              ...
# 155         156         Gaming Electronic Product      Electronics
# 156         157         Camera Electronic Product      Electronics
# 157         158     Smartphone Electronic Product      Electronics
# 158         159              Mystery Book Product            Books
# 159         160         Laptop Electronic Product      Electronics
#
#                               tags  popularity_score
# 0          storage,furniture,decor                68
# 1       cookware,furniture,storage               100
# 2    non-fiction,self-help,mystery                66
# 3          organic,makeup,skincare                75
# 4             winter,summer,casual                69
# ..                             ...               ...
# 155            gaming,camera,audio                85
# 156            audio,camera,gaming                69
# 157       camera,smartphone,laptop                95
# 158  mystery,non-fiction,biography                96
# 159           gaming,camera,laptop                74
#
# [160 rows x 5 columns]

# %%
def recommend_basic(userId):
  user_data = users[users['User_ID'] == userId]

  preference = user_data.Product_Category_Preference.iloc[0]
  print(products[products.category == preference])

# %%
recommend_basic("#10")
# Out:
#      product_id                          title     category  \
# 6             7      Camera Electronic Product  Electronics
# 8             9      Gaming Electronic Product  Electronics
# 14           15      Camera Electronic Product  Electronics
# 15           16      Gaming Electronic Product  Electronics
# 16           17  Smartphone Electronic Product  Electronics
# 18           19      Gaming Electronic Product  Electronics
# 29           30      Laptop Electronic Product  Electronics
# 31           32       Audio Electronic Product  Electronics
# 35           36  Smartphone Electronic Product  Electronics
# 39           40      Gaming Electronic Product  Electronics
# 42           43       Audio Electronic Product  Electronics
# 50           51      Laptop Electronic Product  Electronics
# 71           72       Audio Electronic Product  Electronics
# 72           73       Audio Electronic Product  Electronics
# 75           76       Audio Electronic Product  Electronics
# 76           77      Camera Electronic Product  Electronics
# 78           79      Laptop Electronic Product  Electronics
# 87           88      Gaming Electronic Product  Electronics
# 88           89      Laptop Electronic Product  Electronics
# 89           90      Camera Electronic Product  Electronics
# 91           92       Audio Electronic Product  Electronics
# 93           94      Camera Electronic Product  Electronics
# 94           95      Gaming Electronic Product  Electronics
# 97           98      Gaming Electronic Product  Electronics
# 106         107  Smartphone Electronic Product  Electronics
# 114         115      Camera Electronic Product  Electronics
# 120         121      Laptop Electronic Product  Electronics
# 121         122  Smartphone Electronic Product  Electronics
# 124         125      Camera Electronic Product  Electronics
# 127         128      Gaming Electronic Product  Electronics
# 128         129  Smartphone Electronic Product  Electronics
# 137         138  Smartphone Electronic Product  Electronics
# 143         144      Camera Electronic Product  Electronics
# 148         149  Smartphone Electronic Product  Electronics
# 152         153      Laptop Electronic Product  Electronics
# 154         155      Gaming Electronic Product  Electronics
# 155         156      Gaming Electronic Product  Electronics
# 156         157      Camera Electronic Product  Electronics
# 157         158  Smartphone Electronic Product  Electronics
# 159         160      Laptop Electronic Product  Electronics
#
#                          tags  popularity_score
# 6     smartphone,camera,audio                56
# 8        laptop,gaming,camera                80
# 14   smartphone,gaming,camera                90
# 15        audio,laptop,gaming                73
# 16    audio,gaming,smartphone                70
# 18        camera,gaming,audio                70
# 29        audio,gaming,laptop                60
# 31    audio,smartphone,gaming                85
# 35   laptop,smartphone,gaming                96
# 39   smartphone,gaming,camera                80
# 42        audio,laptop,gaming                72
# 50        camera,audio,laptop                51
# 71    audio,smartphone,camera                52
# 72        audio,gaming,laptop                96
# 75    gaming,audio,smartphone                95
# 76        camera,audio,laptop                63
# 78       laptop,camera,gaming                54
# 87    smartphone,gaming,audio                90
# 88   camera,laptop,smartphone                58
# 89        laptop,audio,camera                74
# 91    audio,camera,smartphone                77
# 93   smartphone,camera,gaming               100
# 94   smartphone,camera,gaming                65
# 97   laptop,smartphone,gaming                54
# 106   camera,audio,smartphone                83
# 114  smartphone,camera,laptop                73
# 120   audio,smartphone,laptop                90
# 121  smartphone,camera,laptop                92
# 124       laptop,audio,camera                76
# 127  camera,gaming,smartphone                97
# 128   smartphone,audio,laptop                50
# 137   smartphone,camera,audio                87
# 143  camera,smartphone,laptop                53
# 148  gaming,laptop,smartphone                92
# 152      camera,gaming,laptop                57
# 154      gaming,camera,laptop                57
# 155       gaming,camera,audio                85
# 156       audio,camera,gaming                69
# 157  camera,smartphone,laptop                95
# 159      gaming,camera,laptop                74

# %%
def popular_products():
  popular = products.sort_values(by="popularity_score",ascending=False)
  print(popular.head(10))

# %%
popular_products()
# Out:
#      product_id                             title         category  \
# 1             2   Cookware Home & Kitchen Product   Home & Kitchen
# 93           94         Camera Electronic Product      Electronics
# 134         135   Fitness Health & Beauty Product  Health & Beauty
# 96           97            Self-help Book Product            Books
# 48           49  Furniture Home & Kitchen Product   Home & Kitchen
# 64           65            Trendy Apparel Product          Apparel
# 147         148            Winter Apparel Product          Apparel
# 115         116              Fiction Book Product            Books
# 153         154    Storage Home & Kitchen Product   Home & Kitchen
# 13           14          Non-fiction Book Product            Books
#
#                               tags  popularity_score
# 1       cookware,furniture,storage               100
# 93        smartphone,camera,gaming               100
# 134        makeup,wellness,fitness                99
# 96     biography,mystery,self-help                98
# 48      cleaning,furniture,storage                98
# 64            formal,casual,trendy                98
# 147           summer,winter,trendy                98
# 115  fiction,non-fiction,self-help                98
# 153     storage,furniture,cleaning                98
# 13   fiction,biography,non-fiction                97

# %%
import numpy as np
import pandas as pd

def generate_interaction_matrix(users, products, num_users=20):
    """
    Simulates a user-product interaction matrix.
    1 = clicked/liked, 0 = no interaction.
    """
    user_ids = users['User_ID'].unique()[:num_users]
    product_ids = products['product_id'].tolist()

    interaction_data = np.random.randint(0, 2, size=(len(user_ids), len(product_ids)))
    interaction_matrix = pd.DataFrame(interaction_data, index=user_ids, columns=product_ids)

    return interaction_matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_similar_users(interaction_matrix, target_user_id, top_n=3):
    """
    Finds top_n users similar to target_user_id using cosine similarity.
    """
    user_vector = interaction_matrix.loc[target_user_id].values.reshape(1, -1)
    similarity_scores = cosine_similarity(user_vector, interaction_matrix.values)[0]

    similar_users = interaction_matrix.index[np.argsort(similarity_scores)[::-1][1:top_n+1]]
    return similar_users

# %%
def recommend_collaborative(user_id, interaction_matrix, products, top_n=5):
    """
    Recommends products liked by similar users that the target user hasn't seen.
    """
    similar_users = get_similar_users(interaction_matrix, user_id)

    user_products = interaction_matrix.loc[user_id]
    unseen_products = user_products[user_products == 0].index

    scores = {}
    for product in unseen_products:
        score = interaction_matrix.loc[similar_users, product].sum()
        scores[product] = score

    recommended_product_ids = sorted(scores, key=scores.get, reverse=True)[:top_n]
    return products[products['product_id'].isin(recommended_product_ids)]

# %%
# Generate interaction matrix
interaction_matrix = generate_interaction_matrix(users, products)

# Recommend for a user
recommend_collaborative("#10", interaction_matrix, products)
# Out:
#      product_id                             title         category  \
# 2             3          Non-fiction Book Product            Books
# 19           20   Organic Health & Beauty Product  Health & Beauty
# 127         128         Gaming Electronic Product      Electronics
# 129         130            Trendy Apparel Product          Apparel
# 130         131  Wellness Health & Beauty Product  Health & Beauty
#
#                               tags  popularity_score
# 2    non-fiction,self-help,mystery                66
# 19       organic,skincare,wellness                80
# 127       camera,gaming,smartphone                97
# 129           winter,trendy,casual                81
# 130       skincare,wellness,makeup                75
